# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def plotthecurve(xdata,ydata,xlbl,ylbl):    
    f, ax = plt.subplots(1)
    f.set_size_inches(10,10) 
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    ax.plot(xdata, ydata,'bo-')
    ax.set_ylim(ymin=0)
    ax.set_xlim(xmin=0) 
    
    major_ticks = np.arange(0, 101, 20)                                              
    minor_ticks = np.arange(0, 101, 5)                                               

    ax.set_xticks(np.arange(0,max(xdata)*1.1,max(xdata)/10)) 
    ax.set_xticks(np.arange(0,max(xdata)*1.1,max(xdata)/50),minor=True)   
    #ax.set_xticks(minor_ticks, minor=True)
    ax.set_yticks(np.arange(0,max(ydata)*1.1,max(ydata)/10))
    ax.set_yticks(np.arange(0,max(ydata)*1.1,max(ydata)/50),minor=True)
    #ax.set_yticks(major_ticks)                                                       
    #ax.set_yticks(minor_ticks, minor=True)  
    ax.grid(which='both')                                                            

    # Grid Bar Opacity:                               
    ax.grid(which='minor', alpha=0.3)                                                
    ax.grid(which='major', alpha=0.8) 

    plt.show(f)

# %%
xdata = [x for x in range(35,129,5)] + [x for x in range(130,139,2)] 
ydata = [1156,
        1164,
        1170,
        1184,
        1194,
        1206,
        1240,
        1265,
        1292,
        1294,
        1328,
        1369,
        1419,
        1480,
        1563,
        1676,
        1799,
        1898,
        1950,
        1929,
        1892,
        1851,
        1805,
        1786]
ydata = [x/0.2989 for x in ydata]
plotthecurve(xdata,ydata,'Temperature$^oC$','Dielectric Const')

# %%
for x,y in zip(xdata,ydata):
    print("%0.2f %0.2f" %( x,y))
# Out:
# 35.00 3867.51
# 40.00 3894.28
# 45.00 3914.35
# 50.00 3961.19
# 55.00 3994.65
# 60.00 4034.79
# 65.00 4148.54
# 70.00 4232.18
# 75.00 4322.52
# 80.00 4329.21
# 85.00 4442.96
# 90.00 4580.13
# 95.00 4747.41
# 100.00 4951.49
# 105.00 5229.17
# 110.00 5607.23
# 115.00 6018.74
# 120.00 6349.95
# 125.00 6523.92
# 130.00 6453.66
# 132.00 6329.88
# 134.00 6192.71
# 136.00 6038.81
# 138.00 5975.24
