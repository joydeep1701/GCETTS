# %%
# %matplotlib inline
import gcetts

# %%
V = [0 ,9, 19,24,30,37,43,51,53,60,62]
I = [25,21,18,15,13,11, 7, 5, 4, 2, 0]
V = [x*0.001 for x in V]
I = [x*0.01 for x in I]
gcetts.plotthecurve(V,I,'Voltage','Current')

# %%
V = [0 ,81,74,76,83,98,111,127,148,177,216]
I = [45,41,31,29,27,23,20 ,16 ,12 ,5  ,0]
V = [x*0.001 for x in V]
I = [x*0.01 for x in I]
gcetts.plotthecurve(V,I,'Voltage','Current')

# %%
V = [0,41,46,57,68,71,84,89,92,123]
I = [25,18,16,14,12,11,7,4,3,0]
V = [x*0.001 for x in V]
I = [x*0.01 for x in I]
gcetts.plotthecurve(V,I,'Voltage','Current')
