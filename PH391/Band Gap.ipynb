# %% [markdown]
# # Band Gap

# %%
# %matplotlib inline
import gcetts

# %%
import math
V = [35.9,35.5,33.2,31.5,28.8,26.0,22.6,19.4,17.0,14.7,12.5,10.6,9.1,7.7,6.6,5.7,4.9,4.2,3.8]
t = [x for x in range(30,121,5)]
T = [x+273 for x in range(30,121,5)]
TI = [1/(x+273) for x in range(30,121,5)]
I = 4.0
S = 0.2
G7ws = 5.54
P_O = [v/I*2*3.14*S for v in V]
P = [x/G7ws for x in P_O]
for m,n,b,v,c,x in zip(V,t,T,TI,P_O,P):
    print("%0.2f   %0.2f   %0.2f   %0.2f   %0.2f   %0.2f    %0.2f"%(m,n,b,v*1000,c*1000,x*1000,math.log(x*1000)))
# Out:
# 35.90   30.00   303.00   3.30   11272.60   2034.77    7.62
# 35.50   35.00   308.00   3.25   11147.00   2012.09    7.61
# 33.20   40.00   313.00   3.19   10424.80   1881.73    7.54
# 31.50   45.00   318.00   3.14   9891.00   1785.38    7.49
# 28.80   50.00   323.00   3.10   9043.20   1632.35    7.40
# 26.00   55.00   328.00   3.05   8164.00   1473.65    7.30
# 22.60   60.00   333.00   3.00   7096.40   1280.94    7.16
# 19.40   65.00   338.00   2.96   6091.60   1099.57    7.00
# 17.00   70.00   343.00   2.92   5338.00   963.54    6.87
# 14.70   75.00   348.00   2.87   4615.80   833.18    6.73
# 12.50   80.00   353.00   2.83   3925.00   708.48    6.56
# 10.60   85.00   358.00   2.79   3328.40   600.79    6.40
# 9.10   90.00   363.00   2.75   2857.40   515.78    6.25
# 7.70   95.00   368.00   2.72   2417.80   436.43    6.08
# 6.60   100.00   373.00   2.68   2072.40   374.08    5.92
# 5.70   105.00   378.00   2.65   1789.80   323.07    5.78
# ...

# %%
gcetts.plotthecurve(TI,[math.log(x*1000) for x in P],'$T^{-1}x10^{-3}$','ln(p)')

# %%
V = [3.9,4.3,4.9,5.6,6.4,7.4,8.8,10.1,11.8,14.8,16.7,19.0,22.7,25.7,28.9,31.4,33.4,35.7,36.2]
t = [x for x in range(120,29,-5)]
T = [x+273 for x in range(120,29,-5)]
TI = [1/(x+273) for x in range(120,29,-5)]
I = 4.0
S = 0.2
G7ws = 5.54
P_O = [v/I*2*3.14*S for v in V]
P = [x/G7ws for x in P_O]
for m,n,b,v,c,x in zip(V,t,T,TI,P_O,P):
    print("%0.2f   %0.2f   %0.2f   %0.2f   %0.2f   %0.2f    %0.2f"%(m,n,b,v*1000,c*1000,x*1000,math.log(x*1000)))
gcetts.plotthecurve(TI,[math.log(x*1000) for x in P],'$T^{-1}x10^{-3}$','ln(p)')
# Out:
# 3.90   120.00   393.00   2.54   1224.60   221.05    5.40
# 4.30   115.00   388.00   2.58   1350.20   243.72    5.50
# 4.90   110.00   383.00   2.61   1538.60   277.73    5.63
# 5.60   105.00   378.00   2.65   1758.40   317.40    5.76
# 6.40   100.00   373.00   2.68   2009.60   362.74    5.89
# 7.40   95.00   368.00   2.72   2323.60   419.42    6.04
# 8.80   90.00   363.00   2.75   2763.20   498.77    6.21
# 10.10   85.00   358.00   2.79   3171.40   572.45    6.35
# 11.80   80.00   353.00   2.83   3705.20   668.81    6.51
# 14.80   75.00   348.00   2.87   4647.20   838.84    6.73
# 16.70   70.00   343.00   2.92   5243.80   946.53    6.85
# 19.00   65.00   338.00   2.96   5966.00   1076.90    6.98
# 22.70   60.00   333.00   3.00   7127.80   1286.61    7.16
# 25.70   55.00   328.00   3.05   8069.80   1456.64    7.28
# 28.90   50.00   323.00   3.10   9074.60   1638.01    7.40
# 31.40   45.00   318.00   3.14   9859.60   1779.71    7.48
# ...

# %%
len(V)
# Out:
# 20
