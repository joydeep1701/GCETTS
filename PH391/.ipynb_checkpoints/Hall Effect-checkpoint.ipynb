# %% [markdown]
# # Hall Effect

# %%
# %matplotlib inline

# %%
import gcetts

# %% [markdown]
# R = $V_ht/IH$

# %%
I = [i*0.01 for i in range(1,13)]
H = [0.149,0.222,0.406,0.528,0.727,0.955,1.055,1.225,1.433,1.559,1.761,1.842]
gcetts.plotthecurve(I,H, 'Magnetizing Current', 'Magnetic Field')

# %%
I = [x*0.1 for x in range(0,41,5)]
V = [3.7,16.2,20.2,26.3,31,40.9,47.4,55.4,63.1]
gcetts.plotthecurve(I,V,'Hall Current','Hall Voltage')

# %%
V = [37.2,37.6,37.8,38.3,39.1,39.9,41.1,41.5,42.1,42.6]
H = [0.149,0.222,0.406,0.528,0.727,1.055,1.433,1.559,1.761,1.842]
gcetts.plotthecurve(V,H,'Hall Voltage','Magnetizing Field')
