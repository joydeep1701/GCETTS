# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
def plotthecurve(xdata,ydata,xlbl,ylbl):    
    f, ax = plt.subplots(1)
    f.set_size_inches(12,12) 
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    ax.plot(xdata, ydata,'bo-')
    ax.set_ylim(ymin=0)
    ax.set_xlim(xmin=0) 
    
    major_ticks = np.arange(0, 101, 20)                                              
    minor_ticks = np.arange(0, 101, 5)                                               

    ax.set_xticks(np.arange(0,max(xdata)*1.1,max(xdata)/10)) 
    ax.set_xticks(np.arange(0,max(xdata)*1.1,max(xdata)/50),minor=True)   
    #ax.set_xticks(minor_ticks, minor=True)
    ax.set_yticks(np.arange(0,max(ydata)*1.1,max(ydata)/10))
    ax.set_yticks(np.arange(0,max(ydata)*1.1,max(ydata)/50),minor=True)
    #ax.set_yticks(major_ticks)                                                       
    #ax.set_yticks(minor_ticks, minor=True)  
    ax.grid(which='both')                                                            

    # Grid Bar Opacity:                               
    ax.grid(which='minor', alpha=0.3)                                                
    ax.grid(which='major', alpha=0.8) 

    plt.show(f)

# %%
yvalues = [
    10,
    8,
    6,
    8,
    18,
    16,
    14,
    12,
    8,
    24,
    22,
    30,
    28,
    12,
    14,
    18,
    35,
    18,
    49,
    22,
    46,
    36,
    56,
]
xvalues = [x for x in range(18,38,2)] + [37,39] + [x for x in range(40,46,2)] + [45] + [x for x in range(50,75,6)] + [80,84]

# %%
plotthecurve(xvalues,yvalues,'$V_{G2K}$','Current-I x $10^{-9}$')

# %%
yvalues = [    6,
    9,
    12,
    10,
    8,
    20,
    18,
    8,
    13,
    30,
    26,
    12,
    32,
    18,
    56,
    40,
    24,
    26,
    48,
    34,
    50, ]
xvalues = [
    9,
    8,
    10,
    11,
    22,
    28,
    30,
    32,
    34,
    38,
    40,
    44,
    50,
    56,
    62,
    63,
    66,
    68,
    76,
    80,
    86,
]
plotthecurve(xvalues,yvalues,'$V_{G2K}$','Current-I x $10^{-9}$')
